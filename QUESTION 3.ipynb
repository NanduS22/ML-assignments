# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:\\Users\\HP\\Desktop\\DATA SETS\\only_road_accidents_data3.csv')
df.head()
# Out:
#         STATE/UT  YEAR  0-3 hrs. (Night)  3-6 hrs. (Night)  6-9 hrs (Day)  \
# 0  A & N Islands  2001                 2                 6             29
# 1  A & N Islands  2002                 2                 6             22
# 2  A & N Islands  2003                 2                 8             31
# 3  A & N Islands  2004                 2                 5             29
# 4  A & N Islands  2005                 0                 8             27
#
#    9-12 hrs (Day)  12-15 hrs (Day)  15-18 hrs (Day)  18-21 hrs (Night)  \
# 0              40               39               40                 18
# 1              41               33               33                 23
# 2              35               28               36                 25
# 3              42               43               43                 37
# 4              28               38               42                 50
#
#    21-24 hrs (Night)  Total
# 0                  7    181
# 1                  8    168
# ...

# %%
df.shape
# Out:
# (490, 11)

# %%
df.columns
# Out:
# Index(['STATE/UT', 'YEAR', '0-3 hrs. (Night)', '3-6 hrs. (Night)',
#        '6-9 hrs (Day)', '9-12 hrs (Day)', '12-15 hrs (Day)', '15-18 hrs (Day)',
#        '18-21 hrs (Night)', '21-24 hrs (Night)', 'Total'],
#       dtype='object')

# %% [markdown]
# # HISTOGRAM

# %%
plt.figure(figsize=(20,20))
plt.hist(df['Total'])
# Out:
# (array([304.,  61.,  25.,  25.,  23.,  28.,  13.,   3.,   7.,   1.]),
#  array([    0.,  7548., 15096., 22644., 30192., 37740., 45288., 52836.,
#         60384., 67932., 75480.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # BOXPLOT

# %%
sns.boxplot(df['Total'])
# Out:
# <AxesSubplot:xlabel='Total'>

# %% [markdown]
# # SCATTER PLOT

# %%
plt.scatter(df['Total'],df['YEAR'])
plt.show()
