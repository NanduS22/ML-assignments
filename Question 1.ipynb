# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:\\Users\\HP\\Desktop\\DATA SETS\\Fuel_Consumption_2000-2022.csv')
df
# Out:
#        YEAR   MAKE        MODEL  VEHICLE CLASS  ENGINE SIZE  CYLINDERS  \
# 0      2000  ACURA        1.6EL        COMPACT          1.6          4
# 1      2000  ACURA        1.6EL        COMPACT          1.6          4
# 2      2000  ACURA        3.2TL       MID-SIZE          3.2          6
# 3      2000  ACURA        3.5RL       MID-SIZE          3.5          6
# 4      2000  ACURA      INTEGRA     SUBCOMPACT          1.8          4
# ...     ...    ...          ...            ...          ...        ...
# 22551  2022  Volvo  XC40 T5 AWD     SUV: Small          2.0          4
# 22552  2022  Volvo  XC60 B5 AWD     SUV: Small          2.0          4
# 22553  2022  Volvo  XC60 B6 AWD     SUV: Small          2.0          4
# 22554  2022  Volvo  XC90 T5 AWD  SUV: Standard          2.0          4
# 22555  2022  Volvo  XC90 T6 AWD  SUV: Standard          2.0          4
#
#       TRANSMISSION FUEL  FUEL CONSUMPTION  HWY (L/100 km)  COMB (L/100 km)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22556 entries, 0 to 22555
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   YEAR              22556 non-null  int64
#  1   MAKE              22556 non-null  object
#  2   MODEL             22556 non-null  object
#  3   VEHICLE CLASS     22556 non-null  object
#  4   ENGINE SIZE       22556 non-null  float64
#  5   CYLINDERS         22556 non-null  int64
#  6   TRANSMISSION      22556 non-null  object
#  7   FUEL              22556 non-null  object
#  8   FUEL CONSUMPTION  22556 non-null  float64
#  9   HWY (L/100 km)    22556 non-null  float64
#  10  COMB (L/100 km)   22556 non-null  float64
#  11  COMB (mpg)        22556 non-null  int64
#  12  EMISSIONS         22556 non-null  int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 2.2+ MB

# %%
df.columns
# Out:
# Index(['YEAR', 'MAKE', 'MODEL', 'VEHICLE CLASS', 'ENGINE SIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUEL', 'FUEL CONSUMPTION', 'HWY (L/100 km)',
#        'COMB (L/100 km)', 'COMB (mpg)', 'EMISSIONS'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# YEAR                0
# MAKE                0
# MODEL               0
# VEHICLE CLASS       0
# ENGINE SIZE         0
# CYLINDERS           0
# TRANSMISSION        0
# FUEL                0
# FUEL CONSUMPTION    0
# HWY (L/100 km)      0
# COMB (L/100 km)     0
# COMB (mpg)          0
# EMISSIONS           0
# dtype: int64

# %%
#there are no null values in the data set

# %%
df['YEAR'].value_counts()
# Out:
# 2015    1132
# 2016    1110
# 2009    1092
# 2018    1083
# 2012    1081
# 2008    1079
# 2011    1076
# 2017    1058
# 2013    1058
# 2019    1056
# 2007    1043
# 2014    1040
# 2010    1021
# 2005    1019
# 2020     968
# 2006     968
# 2022     955
# 2021     941
# 2004     898
# 2003     820
# 2002     740
# 2001     679
# 2000     639
# Name: YEAR, dtype: int64

# %%
df.shape
# Out:
# (22555, 13)

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (22555, 13)

# %%
df['FUEL'].unique()
# Out:
# array(['X', 'Z', 'E', 'N', 'D'], dtype=object)

# %%
df.describe()
# Out:
#                YEAR   ENGINE SIZE     CYLINDERS  FUEL CONSUMPTION  \
# count  22556.000000  22556.000000  22556.000000      22556.000000
# mean    2011.554442      3.356646      5.854141         12.763513
# std        6.298269      1.335425      1.819597          3.500999
# min     2000.000000      0.800000      2.000000          3.500000
# 25%     2006.000000      2.300000      4.000000         10.400000
# 50%     2012.000000      3.000000      6.000000         12.300000
# 75%     2017.000000      4.200000      8.000000         14.725000
# max     2022.000000      8.400000     16.000000         30.600000
#
#        HWY (L/100 km)  COMB (L/100 km)    COMB (mpg)     EMISSIONS
# count    22556.000000     22556.000000  22556.000000  22556.000000
# mean         8.919126        11.034341     27.374534    250.068452
# std          2.274764         2.910920      7.376982     59.355276
# min          3.200000         3.600000     11.000000     83.000000
# ...

# %%
df8=df[df['ENGINE SIZE']==8.4]
df8
# Out:
#        YEAR   MAKE                    MODEL VEHICLE CLASS  ENGINE SIZE  \
# 7166   2008  DODGE  VIPER SRT10 CONVERTIBLE    TWO-SEATER          8.4
# 7167   2008  DODGE        VIPER SRT10 COUPE    TWO-SEATER          8.4
# 8237   2009  DODGE  VIPER SRT10 CONVERTIBLE    TWO-SEATER          8.4
# 8238   2009  DODGE        VIPER SRT10 COUPE    TWO-SEATER          8.4
# 9301   2010  DODGE  VIPER SRT10 CONVERTIBLE    TWO-SEATER          8.4
# 9302   2010  DODGE        VIPER SRT10 COUPE    TWO-SEATER          8.4
# 13086  2013    SRT                    VIPER    TWO-SEATER          8.4
# 13087  2013    SRT                VIPER GTS    TWO-SEATER          8.4
# 14136  2014    SRT              VIPER COUPE    TWO-SEATER          8.4
# 14137  2014    SRT          VIPER GTS COUPE    TWO-SEATER          8.4
# 14613  2015  DODGE          VIPER SRT COUPE    TWO-SEATER          8.4
# 15726  2016  DODGE                VIPER SRT    TWO-SEATER          8.4
# ...

# %%
df.shape
# Out:
# (22556, 13)

# %%
df2000=df[df['YEAR']==2000]
df2000
# Out:
#      YEAR   MAKE           MODEL             VEHICLE CLASS  ENGINE SIZE  \
# 0    2000  ACURA           1.6EL                   COMPACT          1.6
# 1    2000  ACURA           1.6EL                   COMPACT          1.6
# 2    2000  ACURA           3.2TL                  MID-SIZE          3.2
# 3    2000  ACURA           3.5RL                  MID-SIZE          3.5
# 4    2000  ACURA         INTEGRA                SUBCOMPACT          1.8
# ..    ...    ...             ...                       ...          ...
# 634  2000  VOLVO   V70 AWD TURBO  STATION WAGON - MID-SIZE          2.4
# 635  2000  VOLVO   V70 GLT TURBO  STATION WAGON - MID-SIZE          2.4
# 636  2000  VOLVO    V70 T5 TURBO  STATION WAGON - MID-SIZE          2.3
# 637  2000  VOLVO    V70 T5 TURBO  STATION WAGON - MID-SIZE          2.3
# 638  2000  VOLVO  V70R AWD TURBO  STATION WAGON - MID-SIZE          2.4
#
#      CYLINDERS TRANSMISSION FUEL  FUEL CONSUMPTION  HWY (L/100 km)  \
# ...

# %%
df2000['MAKE'].value_counts()
# Out:
# CHEVROLET        63
# FORD             62
# DODGE            46
# TOYOTA           43
# GMC              38
# VOLKSWAGEN       36
# BMW              29
# AUDI             22
# MERCEDES-BENZ    22
# PONTIAC          21
# VOLVO            21
# MAZDA            20
# CHRYSLER         19
# NISSAN           19
# HONDA            17
# SATURN           15
# SUZUKI           13
# SUBARU           12
# DAEWOO           10
# HYUNDAI          10
# JAGUAR           10
# SAAB              9
# ACURA             9
# PORSCHE           8
# JEEP              8
# ISUZU             8
# LEXUS             7
# FERRARI           7
# LINCOLN           6
# BUICK             6
# OLDSMOBILE        5
# CADILLAC          5
# LAND ROVER        4
# INFINITI          4
# KIA               4
# PLYMOUTH          1
# Name: MAKE, dtype: int64

# %%
plt.figure(figsize=(20,20))
sns.barplot(x=df2000['ENGINE SIZE'], y=df2000['FUEL CONSUMPTION'])
plt.show()

# %%
df['VEHICLE CLASS'].unique()
# Out:
# array(['COMPACT', 'MID-SIZE', 'SUBCOMPACT', 'STATION WAGON - MID-SIZE',
#        'MINICOMPACT', 'TWO-SEATER', 'STATION WAGON - SMALL', 'FULL-SIZE',
#        'SUV', 'VAN - CARGO', 'VAN - PASSENGER', 'PICKUP TRUCK - STANDARD',
#        'PICKUP TRUCK - SMALL', 'MINIVAN', 'SUV - STANDARD',
#        'SPECIAL PURPOSE VEHICLE', 'SUV - SMALL', 'Compact', 'SUV: Small',
#        'Two-seater', 'Mid-size', 'Minicompact', 'Subcompact',
#        'Station wagon: Small', 'Full-size', 'SUV: Standard',
#        'Special purpose vehicle', 'Pickup truck: Small',
#        'Pickup truck: Standard', 'Minivan', 'Van: Passenger',
#        'Station wagon: Mid-size'], dtype=object)

# %%
#plt.figure(figsize=(20,20))
#plt.pie(df['EMISSIONS']>600, labels=df['MAKE'], autopct='%1.1f%%')
#plt.show()

# %%
plt.hist(df['EMISSIONS'])
# Out:
# (array([2.650e+02, 2.695e+03, 7.945e+03, 6.399e+03, 3.802e+03, 1.178e+03,
#         2.060e+02, 4.400e+01, 1.800e+01, 4.000e+00]),
#  array([ 83. , 135.5, 188. , 240.5, 293. , 345.5, 398. , 450.5, 503. ,
#         555.5, 608. ]),
#  <BarContainer object of 10 artists>)

# %%
acura=df[df['MAKE']=='ACURA']
acura
# Out:
#        YEAR   MAKE       MODEL VEHICLE CLASS  ENGINE SIZE  CYLINDERS  \
# 0      2000  ACURA       1.6EL       COMPACT          1.6          4
# 1      2000  ACURA       1.6EL       COMPACT          1.6          4
# 2      2000  ACURA       3.2TL      MID-SIZE          3.2          6
# 3      2000  ACURA       3.5RL      MID-SIZE          3.5          6
# 4      2000  ACURA     INTEGRA    SUBCOMPACT          1.8          4
# ...     ...    ...         ...           ...          ...        ...
# 16499  2017  ACURA         NSX    TWO-SEATER          3.5          6
# 16500  2017  ACURA     RDX AWD   SUV - SMALL          3.5          6
# 16501  2017  ACURA  RLX HYBRID      MID-SIZE          3.5          6
# 16502  2017  ACURA         TLX       COMPACT          2.4          4
# 16503  2017  ACURA  TLX SH-AWD       COMPACT          3.5          6
#
#       TRANSMISSION FUEL  FUEL CONSUMPTION  HWY (L/100 km)  COMB (L/100 km)  \
# ...

# %%
acura['VEHICLE CLASS'].value_counts()
# Out:
# COMPACT        78
# MID-SIZE       52
# SUBCOMPACT     25
# SUV            20
# SUV - SMALL    14
# TWO-SEATER      8
# Name: VEHICLE CLASS, dtype: int64

# %%
plt.figure(figsize=(20,15))
plt.pie(acura['VEHICLE CLASS'].value_counts(), labels=acura['VEHICLE CLASS'].unique(), autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x23df950dbb0>,
# ...
#  [Text(0.3532373453880422, 1.0417405520681284, 'COMPACT'),
#   Text(-1.0831188875232343, -0.19197259046653398, 'MID-SIZE'),
#   Text(-0.18333044487346936, -1.0846151151364691, 'SUBCOMPACT'),
#   Text(0.5751221644289131, -0.9376750481817262, 'SUV'),
#   Text(0.9764981657911788, -0.5064102410165732, 'TWO-SEATER'),
#   Text(1.0910603242630434, -0.13995488136904183, 'SUV - SMALL')],
#  [Text(0.19267491566620482, 0.5682221193098882, '39.6%'),
#   Text(-0.5907921204672186, -0.10471232207265488, '26.4%'),
#   Text(-0.09999842447643782, -0.5916082446198921, '12.7%'),
#   Text(0.31370299877940705, -0.5114591171900325, '10.2%'),
#   Text(0.5326353631588248, -0.2762237678272217, '7.1%'),
#   Text(0.5951238132343873, -0.07633902620129553, '4.1%')])

# %%
plt.figure(figsize=(30,30))
sns.displot(df['EMISSIONS'])
sns.displot(df['ENGINE SIZE'])

# %%
plt.figure(figsize=(20,20))
sns.barplot(df['ENGINE SIZE'],df['FUEL CONSUMPTION'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ENGINE SIZE', ylabel='FUEL CONSUMPTION'>

# %%
sns.pairplot(acura)

# %%
plt.figure(figsize=(20,20))
df.hist()
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.countplot(x='ENGINE SIZE', data=df)
# Out:
# <AxesSubplot:xlabel='ENGINE SIZE', ylabel='count'>

# %%
df.max()
# Out:
# YEAR                          2022
# MAKE                         Volvo
# MODEL                           xD
# VEHICLE CLASS       Van: Passenger
# ENGINE SIZE                    8.4
# CYLINDERS                       16
# TRANSMISSION                    M7
# FUEL                             Z
# FUEL CONSUMPTION              30.6
# HWY (L/100 km)                20.9
# COMB (L/100 km)               26.1
# COMB (mpg)                      78
# EMISSIONS                      608
# dtype: object

# %%
plt.figure(figsize=(20,20))
sns.countplot(x='FUEL', data=df)
# Out:
# <AxesSubplot:xlabel='FUEL', ylabel='count'>

# %%
plt.figure(figsize=(20,20))
sns.countplot(x='TRANSMISSION', data=df)
# Out:
# <AxesSubplot:xlabel='TRANSMISSION', ylabel='count'>

# %%
pip install ggplot
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 b
#
# NameError: name 'b' is not defined
